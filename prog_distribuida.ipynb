# %%
# !pip install argon2-cffi mpi4py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting argon2-cffi
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting mpi4py
#   Downloading mpi4py-3.1.3.tar.gz (2.5 MB)
#      |████████████████████████████████| 2.5 MB 12.9 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from argon2-cffi) (4.1.1)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#      |████████████████████████████████| 86 kB 4.8 MB/s
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from argon2-cffi-bindings->argon2-cffi) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi) (2.21)
# Building wheels for collected packages: mpi4py
#   Building wheel for mpi4py (PEP 517) ... done
#   Created wheel for mpi4py: filename=mpi4py-3.1.3-cp37-cp37m-linux_x86_64.whl size=2185255 sha256=07e576d170efe883415c01f12cbfaab62faf885a14ff70debc0515b1571ebfe3
#   Stored in directory: /root/.cache/pip/wheels/7a/07/14/6a0c63fa2c6e473c6edc40985b7d89f05c61ff25ee7f0ad9ac
# Successfully built mpi4py
# Installing collected packages: argon2-cffi-bindings, mpi4py, argon2-cffi
# Successfully installed argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 mpi4py-3.1.3

# %%
import requests
import time
from argon2 import PasswordHasher

# %%
## Programa sem Distribuição

start = time.time()
input = 'blowjob'
hasher = PasswordHasher()
hash = hasher.hash(input)
with open('./wordlist.txt','r') as wordlist:
    for password in wordlist.readlines():
        try:
            aux_password = password.strip()
            hasher.verify(hash, aux_password)
            print('Password: {}'.format(aux_password))
            break
        except:
            if hasher.check_needs_rehash(hash):
                hash = hasher.hash(input)
            pass

print('Time execution: {} s'.format(time.time() - start))
# Out:
# Password: blowjob
# Time execution: 13.716091871261597 s

# %%
# !mpirun --allow-run-as-root -np 1 python ./main.py
# Out:
# Password (blowjob) find by process 0 in 12.523661136627197 s

# %%
# !mpirun --allow-run-as-root -np 2 python ./main.py
# Out:
# Password (blowjob) find by process 1 in 10.385637044906616 s
# Total time execution by process 0: 13.019186973571777 s

# %%
# !mpirun --allow-run-as-root -np 4 python ./main.py
# Out:
# Password (blowjob) find by process 3 in 6.300201177597046 s
# Total time execution by process 0: 13.330367803573608 s
# Total time execution by process 1: 13.430298089981079 s
# Total time execution by process 2: 13.516948223114014 s

# %%
# !mpirun --allow-run-as-root -np 5 python ./main.py
# Out:
# Password (blowjob) find by process 4 in 4.414475679397583 s
# Total time execution by process 3: 13.182502508163452 s
# Total time execution by process 1: 13.54099154472351 s
# Total time execution by process 2: 13.649890661239624 s
# Total time execution by process 0: 13.677448034286499 s
